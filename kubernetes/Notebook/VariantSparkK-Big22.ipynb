# %% [markdown]
# # VariantSpark on Kubernetes
#
#
# This notebook is designed to run inside a kubernetes cluster.  This makes it possible to use kubernetes internal DNS to find the MASTER node.  It also means that the configuration of the pod this notebook container is running in can provide the security token needed to authenticate with the kubernetes API (spark submit already knows where to look for this token).
#
# You will need to create an S3 bucket, and put the input files in there, then set the INPUT_BUCKET variable in the cell below.
#
# Then run the cell and wait.  There is very little feedback while the job is running, but you can view the Kubernetes UI to see the pods as they work.

# %%
# %%bash
#
# set -e
#
# MASTER=https://kubernetes.default.svc:443
# INPUT_BUCKET=variant-spark
#
# function fatal_error () {
# 	echo "ERROR: $1" 1>&2
# 	exit 1
# }
#
# if [ -z ${MASTER+x} ];
#     then
#         echo "You must set the MASTER environment variable to a kubernetes API endpoint";
#         echo "Example: https://ABC.sk1.us-west-2.eks.amazonaws.com:443"
#         exit 1
# fi
#
# if [ -z ${INPUT_BUCKET+x} ];
#     then
#         echo "You must set the INPUT_BUCKET environment variable to a bucket containing input data";
#         echo "Example: variant-spark-k-storage"
#         exit 1
# fi
#
# [[ $(type -P "spark-submit") ]] || fatal_error  "\`spark-submit\` cannot be found. Please make sure it's on your PATH."
#
# spark-submit \
#     --class au.csiro.variantspark.cli.VariantSparkApp \
#     --driver-class-path ./conf \
#     --master k8s://${MASTER} \
#     --deploy-mode cluster \
#     --name VariantSpark \
#     --conf spark.kubernetes.authenticate.driver.serviceAccountName=spark \
#     --conf spark.executor.instances=6 \
#     --conf spark.kubernetes.container.image=jamesrcounts/variantspark:002 \
#     --jars http://central.maven.org/maven2/org/apache/hadoop/hadoop-aws/2.7.3/hadoop-aws-2.7.3.jar,http://central.maven.org/maven2/com/amazonaws/aws-java-sdk/1.7.4/aws-java-sdk-1.7.4.jar,http://central.maven.org/maven2/joda-time/joda-time/2.9.9/joda-time-2.9.9.jar \
#     local:///opt/spark/jars/variant-spark_2.11-0.2.0-SNAPSHOT-all.jar importance \
#         -if s3a://${INPUT_BUCKET}/datasets/big-examples/ALL.chr22.phase1_release_v3.20101123.snps_indels_svs.genotypes.vcf.bz2 \
#         -ff s3a://${INPUT_BUCKET}/datasets/big-examples/chr22-labels_release_v3.20101123.csv \
#         -fc 22_16051249 \
#         -v \
#         -rn 500 \
#         -rbs 20 \
#         -ro "$@"
# Out:
# 2018-07-16 17:18:57 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-1801cf9887ee3567a64e2832cc92f0ce-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-665d1151651446f4899bbd606720319c, spark-role -> driver
# 	 pod uid: 52b962d6-891c-11e8-b462-0684c082eba0
# 	 creation time: 2018-07-16T17:18:57Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-l58n5
# 	 node name: N/A
# 	 start time: N/A
# 	 container images: N/A
# 	 phase: Pending
# 	 status: []
# 2018-07-16 17:18:57 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-1801cf9887ee3567a64e2832cc92f0ce-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-665d1151651446f4899bbd606720319c, spark-role -> driver
# 	 pod uid: 52b962d6-891c-11e8-b462-0684c082eba0
# 	 creation time: 2018-07-16T17:18:57Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-l58n5
# 	 node name: ip-10-0-102-45.us-west-2.compute.internal
# 	 start time: N/A
# 	 container images: N/A
# 	 phase: Pending
# 	 status: []
# 2018-07-16 17:18:57 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-1801cf9887ee3567a64e2832cc92f0ce-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-665d1151651446f4899bbd606720319c, spark-role -> driver
# 	 pod uid: 52b962d6-891c-11e8-b462-0684c082eba0
# 	 creation time: 2018-07-16T17:18:57Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-l58n5
# 	 node name: ip-10-0-102-45.us-west-2.compute.internal
# 	 start time: 2018-07-16T17:18:57Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Pending
# 	 status: [ContainerStatus(containerID=null, image=jamesrcounts/variantspark:002, imageID=, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=false, restartCount=0, state=ContainerState(running=null, terminated=null, waiting=ContainerStateWaiting(message=null, reason=PodInitializing, additionalProperties={}), additionalProperties={}), additionalProperties={})]
# 2018-07-16 17:18:57 INFO  Client:54 - Waiting for application VariantSpark to finish...
# 2018-07-16 17:18:59 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-1801cf9887ee3567a64e2832cc92f0ce-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-665d1151651446f4899bbd606720319c, spark-role -> driver
# 	 pod uid: 52b962d6-891c-11e8-b462-0684c082eba0
# 	 creation time: 2018-07-16T17:18:57Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-l58n5
# 	 node name: ip-10-0-102-45.us-west-2.compute.internal
# 	 start time: 2018-07-16T17:18:57Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Pending
# 	 status: [ContainerStatus(containerID=null, image=jamesrcounts/variantspark:002, imageID=, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=false, restartCount=0, state=ContainerState(running=null, terminated=null, waiting=ContainerStateWaiting(message=null, reason=PodInitializing, additionalProperties={}), additionalProperties={}), additionalProperties={})]
# 2018-07-16 17:19:01 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-1801cf9887ee3567a64e2832cc92f0ce-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-665d1151651446f4899bbd606720319c, spark-role -> driver
# 	 pod uid: 52b962d6-891c-11e8-b462-0684c082eba0
# 	 creation time: 2018-07-16T17:18:57Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-l58n5
# 	 node name: ip-10-0-102-45.us-west-2.compute.internal
# 	 start time: 2018-07-16T17:18:57Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Pending
# 	 status: [ContainerStatus(containerID=null, image=jamesrcounts/variantspark:002, imageID=, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=false, restartCount=0, state=ContainerState(running=null, terminated=null, waiting=ContainerStateWaiting(message=null, reason=PodInitializing, additionalProperties={}), additionalProperties={}), additionalProperties={})]
# 2018-07-16 17:19:02 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-1801cf9887ee3567a64e2832cc92f0ce-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-665d1151651446f4899bbd606720319c, spark-role -> driver
# 	 pod uid: 52b962d6-891c-11e8-b462-0684c082eba0
# 	 creation time: 2018-07-16T17:18:57Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-l58n5
# 	 node name: ip-10-0-102-45.us-west-2.compute.internal
# 	 start time: 2018-07-16T17:18:57Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Running
# 	 status: [ContainerStatus(containerID=docker://047b31c55e105b0d5e9faa3cb677907306c057a0e0725523bf1b5bb8b927d748, image=jamesrcounts/variantspark:002, imageID=docker-pullable://jamesrcounts/variantspark@sha256:788155cb91dbd2edc22868377e8102a02cfae98d2a99be93455ab84001d06685, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=true, restartCount=0, state=ContainerState(running=ContainerStateRunning(startedAt=Time(time=2018-07-16T17:19:02Z, additionalProperties={}), additionalProperties={}), terminated=null, waiting=null, additionalProperties={}), additionalProperties={})]
# 2018-07-16 17:35:10 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-1801cf9887ee3567a64e2832cc92f0ce-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-665d1151651446f4899bbd606720319c, spark-role -> driver
# 	 pod uid: 52b962d6-891c-11e8-b462-0684c082eba0
# 	 creation time: 2018-07-16T17:18:57Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-l58n5
# 	 node name: ip-10-0-102-45.us-west-2.compute.internal
# 	 start time: 2018-07-16T17:18:57Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Succeeded
# 	 status: [ContainerStatus(containerID=docker://047b31c55e105b0d5e9faa3cb677907306c057a0e0725523bf1b5bb8b927d748, image=jamesrcounts/variantspark:002, imageID=docker-pullable://jamesrcounts/variantspark@sha256:788155cb91dbd2edc22868377e8102a02cfae98d2a99be93455ab84001d06685, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=false, restartCount=0, state=ContainerState(running=null, terminated=ContainerStateTerminated(containerID=docker://047b31c55e105b0d5e9faa3cb677907306c057a0e0725523bf1b5bb8b927d748, exitCode=0, finishedAt=Time(time=2018-07-16T17:35:09Z, additionalProperties={}), message=null, reason=Completed, signal=null, startedAt=Time(time=2018-07-16T17:19:02Z, additionalProperties={}), additionalProperties={}), waiting=null, additionalProperties={}), additionalProperties={})]
# 2018-07-16 17:35:10 INFO  LoggingPodStatusWatcherImpl:54 - Container final statuses:
#
#
# 	 Container name: spark-kubernetes-driver
# 	 Container image: jamesrcounts/variantspark:002
# 	 Container state: Terminated
# 	 Exit code: 0
# 2018-07-16 17:35:10 INFO  Client:54 - Application VariantSpark finished.
# 2018-07-16 17:35:10 INFO  ShutdownHookManager:54 - Shutdown hook called
# 2018-07-16 17:35:10 INFO  ShutdownHookManager:54 - Deleting directory /tmp/spark-3fa00f6e-94d1-4c64-8533-b5fcde149697
