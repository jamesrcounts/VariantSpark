# %% [markdown]
# # VariantSpark-k Tiny Warmup Job
#
#
# This notebook is designed to run inside a kubernetes cluster.  This makes it possible to use kubernetes internal DNS to find the MASTER node.  It also means that the configuration of the pod this notebook container is running in can provide the security token needed to authenticate with the kubernetes API (spark submit already knows where to look for this token).
#
# You will need to create an S3 bucket, and put the input files in there, then set the INPUT_BUCKET variable in the cell below.
#
# Then run the cell and wait.  There is very little feedback while the job is running, but you can view the Kubernetes UI to see the pods as they work.

# %%
# %%bash
#
# set -e
#
# MASTER=https://kubernetes.default.svc:443
# INPUT_BUCKET=variant-spark-k-storage20180709164545375200000001
#
# function fatal_error () {
# 	echo "ERROR: $1" 1>&2
# 	exit 1
# }
#
# if [ -z ${MASTER+x} ];
#     then
#         echo "You must set the MASTER environment variable to a kubernetes API endpoint";
#         echo "Example: https://ABC.sk1.us-west-2.eks.amazonaws.com:443"
#         exit 1
# fi
#
# if [ -z ${INPUT_BUCKET+x} ];
#     then
#         echo "You must set the INPUT_BUCKET environment variable to a bucket containing input data";
#         echo "Example: variant-spark-k-storage"
#         exit 1
# fi
#
# [[ $(type -P "spark-submit") ]] || fatal_error  "\`spark-submit\` cannot be found. Please make sure it's on your PATH."
#
# spark-submit \
#     --class au.csiro.variantspark.cli.VariantSparkApp \
#     --driver-class-path ./conf \
#     --master k8s://${MASTER} \
#     --deploy-mode cluster \
#     --name VariantSparkTiny \
#     --conf spark.kubernetes.authenticate.driver.serviceAccountName=spark \
#     --conf spark.executor.instances=6 \
#     --conf spark.kubernetes.container.image=jamesrcounts/variantspark:002 \
#     --jars http://central.maven.org/maven2/org/apache/hadoop/hadoop-aws/2.7.3/hadoop-aws-2.7.3.jar,http://central.maven.org/maven2/com/amazonaws/aws-java-sdk/1.7.4/aws-java-sdk-1.7.4.jar,http://central.maven.org/maven2/joda-time/joda-time/2.9.9/joda-time-2.9.9.jar \
#     local:///opt/spark/jars/variant-spark_2.11-0.2.0-SNAPSHOT-all.jar importance \
#         -if s3a://${INPUT_BUCKET}/input/chr22_1000.vcf \
#         -ff s3a://${INPUT_BUCKET}/input/chr22-labels.csv \
#         -fc 22_16051249 \
#         -v \
#         -rn 500 \
#         -rbs 16 \
#         -ro "$@"
# Out:
# 2018-07-20 06:02:35 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-987c71ba83a03dc09631b93937b7c6f0-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-155ffe62f6d2461f84b6fcf864407099, spark-role -> driver
# 	 pod uid: 7fd27dba-8be2-11e8-a214-020c590774e0
# 	 creation time: 2018-07-20T06:02:35Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-7gmf4
# 	 node name: N/A
# 	 start time: N/A
# 	 container images: N/A
# 	 phase: Pending
# 	 status: []
# 2018-07-20 06:02:35 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-987c71ba83a03dc09631b93937b7c6f0-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-155ffe62f6d2461f84b6fcf864407099, spark-role -> driver
# 	 pod uid: 7fd27dba-8be2-11e8-a214-020c590774e0
# 	 creation time: 2018-07-20T06:02:35Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-7gmf4
# 	 node name: ip-10-0-103-21.us-west-2.compute.internal
# 	 start time: N/A
# 	 container images: N/A
# 	 phase: Pending
# 	 status: []
# 2018-07-20 06:02:35 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-987c71ba83a03dc09631b93937b7c6f0-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-155ffe62f6d2461f84b6fcf864407099, spark-role -> driver
# 	 pod uid: 7fd27dba-8be2-11e8-a214-020c590774e0
# 	 creation time: 2018-07-20T06:02:35Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-7gmf4
# 	 node name: ip-10-0-103-21.us-west-2.compute.internal
# 	 start time: 2018-07-20T06:02:35Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Pending
# 	 status: [ContainerStatus(containerID=null, image=jamesrcounts/variantspark:002, imageID=, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=false, restartCount=0, state=ContainerState(running=null, terminated=null, waiting=ContainerStateWaiting(message=null, reason=PodInitializing, additionalProperties={}), additionalProperties={}), additionalProperties={})]
# 2018-07-20 06:02:36 INFO  Client:54 - Waiting for application VariantSpark to finish...
# 2018-07-20 06:02:38 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-987c71ba83a03dc09631b93937b7c6f0-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-155ffe62f6d2461f84b6fcf864407099, spark-role -> driver
# 	 pod uid: 7fd27dba-8be2-11e8-a214-020c590774e0
# 	 creation time: 2018-07-20T06:02:35Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-7gmf4
# 	 node name: ip-10-0-103-21.us-west-2.compute.internal
# 	 start time: 2018-07-20T06:02:35Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Pending
# 	 status: [ContainerStatus(containerID=null, image=jamesrcounts/variantspark:002, imageID=, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=false, restartCount=0, state=ContainerState(running=null, terminated=null, waiting=ContainerStateWaiting(message=null, reason=PodInitializing, additionalProperties={}), additionalProperties={}), additionalProperties={})]
# 2018-07-20 06:02:40 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-987c71ba83a03dc09631b93937b7c6f0-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-155ffe62f6d2461f84b6fcf864407099, spark-role -> driver
# 	 pod uid: 7fd27dba-8be2-11e8-a214-020c590774e0
# 	 creation time: 2018-07-20T06:02:35Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-7gmf4
# 	 node name: ip-10-0-103-21.us-west-2.compute.internal
# 	 start time: 2018-07-20T06:02:35Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Pending
# 	 status: [ContainerStatus(containerID=null, image=jamesrcounts/variantspark:002, imageID=, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=false, restartCount=0, state=ContainerState(running=null, terminated=null, waiting=ContainerStateWaiting(message=null, reason=PodInitializing, additionalProperties={}), additionalProperties={}), additionalProperties={})]
# 2018-07-20 06:02:41 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-987c71ba83a03dc09631b93937b7c6f0-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-155ffe62f6d2461f84b6fcf864407099, spark-role -> driver
# 	 pod uid: 7fd27dba-8be2-11e8-a214-020c590774e0
# 	 creation time: 2018-07-20T06:02:35Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-7gmf4
# 	 node name: ip-10-0-103-21.us-west-2.compute.internal
# 	 start time: 2018-07-20T06:02:35Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Running
# 	 status: [ContainerStatus(containerID=docker://a5b89d68ae17a425cc3bc71828339648eadcd3a9f6acb71f7536c772af4d1c05, image=jamesrcounts/variantspark:002, imageID=docker-pullable://jamesrcounts/variantspark@sha256:788155cb91dbd2edc22868377e8102a02cfae98d2a99be93455ab84001d06685, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=true, restartCount=0, state=ContainerState(running=ContainerStateRunning(startedAt=Time(time=2018-07-20T06:02:40Z, additionalProperties={}), additionalProperties={}), terminated=null, waiting=null, additionalProperties={}), additionalProperties={})]
# 2018-07-20 06:04:49 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantspark-987c71ba83a03dc09631b93937b7c6f0-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-155ffe62f6d2461f84b6fcf864407099, spark-role -> driver
# 	 pod uid: 7fd27dba-8be2-11e8-a214-020c590774e0
# 	 creation time: 2018-07-20T06:02:35Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-7gmf4
# 	 node name: ip-10-0-103-21.us-west-2.compute.internal
# 	 start time: 2018-07-20T06:02:35Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Succeeded
# 	 status: [ContainerStatus(containerID=docker://a5b89d68ae17a425cc3bc71828339648eadcd3a9f6acb71f7536c772af4d1c05, image=jamesrcounts/variantspark:002, imageID=docker-pullable://jamesrcounts/variantspark@sha256:788155cb91dbd2edc22868377e8102a02cfae98d2a99be93455ab84001d06685, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=false, restartCount=0, state=ContainerState(running=null, terminated=ContainerStateTerminated(containerID=docker://a5b89d68ae17a425cc3bc71828339648eadcd3a9f6acb71f7536c772af4d1c05, exitCode=0, finishedAt=Time(time=2018-07-20T06:04:48Z, additionalProperties={}), message=null, reason=Completed, signal=null, startedAt=Time(time=2018-07-20T06:02:40Z, additionalProperties={}), additionalProperties={}), waiting=null, additionalProperties={}), additionalProperties={})]
# 2018-07-20 06:04:49 INFO  LoggingPodStatusWatcherImpl:54 - Container final statuses:
#
#
# 	 Container name: spark-kubernetes-driver
# 	 Container image: jamesrcounts/variantspark:002
# 	 Container state: Terminated
# 	 Exit code: 0
# 2018-07-20 06:04:49 INFO  Client:54 - Application VariantSpark finished.
# 2018-07-20 06:04:49 INFO  ShutdownHookManager:54 - Shutdown hook called
# 2018-07-20 06:04:49 INFO  ShutdownHookManager:54 - Deleting directory /tmp/spark-2546ba58-5cd8-4da4-832e-54def7b29066
