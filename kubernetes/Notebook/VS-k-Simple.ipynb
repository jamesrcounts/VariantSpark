# %% [markdown]
# # VariantSpark-k Tiny Warmup Job
#
#
# This notebook is designed to run inside a kubernetes cluster.  This makes it possible to use kubernetes internal DNS to find the MASTER node.  It also means that the configuration of the pod this notebook container is running in can provide the security token needed to authenticate with the kubernetes API (spark submit already knows where to look for this token).
#
# You will need to create an S3 bucket, and put the input files in there, then set the INPUT_BUCKET variable in the cell below.
#
# Then run the cell and wait.  There is very little feedback while the job is running, but you can view the Kubernetes UI to see the pods as they work.

# %%
# %%bash
#
# set -e
#
# MASTER=https://kubernetes.default.svc:443
# INPUT_BUCKET=variant-spark-k-storage20180709164545375200000001
#
# function fatal_error () {
# 	echo "ERROR: $1" 1>&2
# 	exit 1
# }
#
# if [ -z ${MASTER+x} ];
#     then
#         echo "You must set the MASTER environment variable to a kubernetes API endpoint";
#         echo "Example: https://ABC.sk1.us-west-2.eks.amazonaws.com:443"
#         exit 1
# fi
#
# if [ -z ${INPUT_BUCKET+x} ];
#     then
#         echo "You must set the INPUT_BUCKET environment variable to a bucket containing input data";
#         echo "Example: variant-spark-k-storage"
#         exit 1
# fi
#
# [[ $(type -P "spark-submit") ]] || fatal_error  "\`spark-submit\` cannot be found. Please make sure it's on your PATH."
#
# spark-submit \
#     --class au.csiro.variantspark.cli.VariantSparkApp \
#     --driver-class-path ./conf \
#     --master k8s://${MASTER} \
#     --deploy-mode cluster \
#     --name VariantSparkTiny \
#     --conf spark.kubernetes.authenticate.driver.serviceAccountName=spark \
#     --conf spark.executor.instances=6 \
#     --conf spark.kubernetes.container.image=jamesrcounts/variantspark:002 \
#     --jars http://central.maven.org/maven2/org/apache/hadoop/hadoop-aws/2.7.3/hadoop-aws-2.7.3.jar,http://central.maven.org/maven2/com/amazonaws/aws-java-sdk/1.7.4/aws-java-sdk-1.7.4.jar,http://central.maven.org/maven2/joda-time/joda-time/2.9.9/joda-time-2.9.9.jar \
#     local:///opt/spark/jars/variant-spark_2.11-0.2.0-SNAPSHOT-all.jar importance \
#         -if s3a://${INPUT_BUCKET}/input/chr22_1000.vcf \
#         -ff s3a://${INPUT_BUCKET}/input/chr22-labels.csv \
#         -fc 22_16051249 \
#         -v \
#         -rn 500 \
#         -rbs 16 \
#         -ro "$@"
# Out:
# 2018-08-02 01:48:54 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantsparktiny-b9741d606b9038519219e76490473771-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-a0c55a7a81fb4375a496baec61655a7b, spark-role -> driver
# 	 pod uid: 3645152f-95f6-11e8-89aa-0a6dc91e79ec
# 	 creation time: 2018-08-02T01:48:53Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-nm5f2
# 	 node name: N/A
# 	 start time: N/A
# 	 container images: N/A
# 	 phase: Pending
# 	 status: []
# 2018-08-02 01:48:54 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantsparktiny-b9741d606b9038519219e76490473771-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-a0c55a7a81fb4375a496baec61655a7b, spark-role -> driver
# 	 pod uid: 3645152f-95f6-11e8-89aa-0a6dc91e79ec
# 	 creation time: 2018-08-02T01:48:53Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-nm5f2
# 	 node name: ip-10-0-103-149.us-west-2.compute.internal
# 	 start time: N/A
# 	 container images: N/A
# 	 phase: Pending
# 	 status: []
# 2018-08-02 01:48:54 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantsparktiny-b9741d606b9038519219e76490473771-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-a0c55a7a81fb4375a496baec61655a7b, spark-role -> driver
# 	 pod uid: 3645152f-95f6-11e8-89aa-0a6dc91e79ec
# 	 creation time: 2018-08-02T01:48:53Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-nm5f2
# 	 node name: ip-10-0-103-149.us-west-2.compute.internal
# 	 start time: 2018-08-02T01:48:54Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Pending
# 	 status: [ContainerStatus(containerID=null, image=jamesrcounts/variantspark:002, imageID=, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=false, restartCount=0, state=ContainerState(running=null, terminated=null, waiting=ContainerStateWaiting(message=null, reason=PodInitializing, additionalProperties={}), additionalProperties={}), additionalProperties={})]
# 2018-08-02 01:48:54 INFO  Client:54 - Waiting for application VariantSparkTiny to finish...
# 2018-08-02 01:48:55 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantsparktiny-b9741d606b9038519219e76490473771-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-a0c55a7a81fb4375a496baec61655a7b, spark-role -> driver
# 	 pod uid: 3645152f-95f6-11e8-89aa-0a6dc91e79ec
# 	 creation time: 2018-08-02T01:48:53Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-nm5f2
# 	 node name: ip-10-0-103-149.us-west-2.compute.internal
# 	 start time: 2018-08-02T01:48:54Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Pending
# 	 status: [ContainerStatus(containerID=null, image=jamesrcounts/variantspark:002, imageID=, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=false, restartCount=0, state=ContainerState(running=null, terminated=null, waiting=ContainerStateWaiting(message=null, reason=PodInitializing, additionalProperties={}), additionalProperties={}), additionalProperties={})]
# 2018-08-02 01:48:57 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantsparktiny-b9741d606b9038519219e76490473771-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-a0c55a7a81fb4375a496baec61655a7b, spark-role -> driver
# 	 pod uid: 3645152f-95f6-11e8-89aa-0a6dc91e79ec
# 	 creation time: 2018-08-02T01:48:53Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-nm5f2
# 	 node name: ip-10-0-103-149.us-west-2.compute.internal
# 	 start time: 2018-08-02T01:48:54Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Pending
# 	 status: [ContainerStatus(containerID=null, image=jamesrcounts/variantspark:002, imageID=, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=false, restartCount=0, state=ContainerState(running=null, terminated=null, waiting=ContainerStateWaiting(message=null, reason=PodInitializing, additionalProperties={}), additionalProperties={}), additionalProperties={})]
# 2018-08-02 01:48:58 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantsparktiny-b9741d606b9038519219e76490473771-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-a0c55a7a81fb4375a496baec61655a7b, spark-role -> driver
# 	 pod uid: 3645152f-95f6-11e8-89aa-0a6dc91e79ec
# 	 creation time: 2018-08-02T01:48:53Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-nm5f2
# 	 node name: ip-10-0-103-149.us-west-2.compute.internal
# 	 start time: 2018-08-02T01:48:54Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Running
# 	 status: [ContainerStatus(containerID=docker://ef1af1fea6c020582b097d17d5cb211d8dca6976765fce2587a7d772c7c24f1c, image=jamesrcounts/variantspark:002, imageID=docker-pullable://jamesrcounts/variantspark@sha256:788155cb91dbd2edc22868377e8102a02cfae98d2a99be93455ab84001d06685, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=true, restartCount=0, state=ContainerState(running=ContainerStateRunning(startedAt=Time(time=2018-08-02T01:48:58Z, additionalProperties={}), additionalProperties={}), terminated=null, waiting=null, additionalProperties={}), additionalProperties={})]
# 2018-08-02 01:50:44 INFO  LoggingPodStatusWatcherImpl:54 - State changed, new state:
# 	 pod name: variantsparktiny-b9741d606b9038519219e76490473771-driver
# 	 namespace: default
# 	 labels: spark-app-selector -> spark-a0c55a7a81fb4375a496baec61655a7b, spark-role -> driver
# 	 pod uid: 3645152f-95f6-11e8-89aa-0a6dc91e79ec
# 	 creation time: 2018-08-02T01:48:53Z
# 	 service account name: spark
# 	 volumes: spark-init-properties, download-jars-volume, download-files-volume, spark-token-nm5f2
# 	 node name: ip-10-0-103-149.us-west-2.compute.internal
# 	 start time: 2018-08-02T01:48:54Z
# 	 container images: jamesrcounts/variantspark:002
# 	 phase: Succeeded
# 	 status: [ContainerStatus(containerID=docker://ef1af1fea6c020582b097d17d5cb211d8dca6976765fce2587a7d772c7c24f1c, image=jamesrcounts/variantspark:002, imageID=docker-pullable://jamesrcounts/variantspark@sha256:788155cb91dbd2edc22868377e8102a02cfae98d2a99be93455ab84001d06685, lastState=ContainerState(running=null, terminated=null, waiting=null, additionalProperties={}), name=spark-kubernetes-driver, ready=false, restartCount=0, state=ContainerState(running=null, terminated=ContainerStateTerminated(containerID=docker://ef1af1fea6c020582b097d17d5cb211d8dca6976765fce2587a7d772c7c24f1c, exitCode=0, finishedAt=Time(time=2018-08-02T01:50:43Z, additionalProperties={}), message=null, reason=Completed, signal=null, startedAt=Time(time=2018-08-02T01:48:58Z, additionalProperties={}), additionalProperties={}), waiting=null, additionalProperties={}), additionalProperties={})]
# 2018-08-02 01:50:44 INFO  LoggingPodStatusWatcherImpl:54 - Container final statuses:
#
#
# 	 Container name: spark-kubernetes-driver
# 	 Container image: jamesrcounts/variantspark:002
# 	 Container state: Terminated
# 	 Exit code: 0
# 2018-08-02 01:50:44 INFO  Client:54 - Application VariantSparkTiny finished.
# 2018-08-02 01:50:44 INFO  ShutdownHookManager:54 - Shutdown hook called
# 2018-08-02 01:50:44 INFO  ShutdownHookManager:54 - Deleting directory /tmp/spark-4ccb1858-f0c2-4295-9676-eb03a75cf5f2
